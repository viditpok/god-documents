# %% [markdown]
# # Validation EDA
# placeholder workflow for exploratory checks on synthetic samples.

# %%
# guideline §6 discussion l53-l74from src.data.loader import DataRequest, load_synthetic_compustatfrom src.data.cleaner import winsorize_relative_to_assetsrequest = DataRequest(start='2010-01', end='2010-02')comp = load_synthetic_compustat(request)winsorized = winsorize_relative_to_assets(comp)winsorized.head()
